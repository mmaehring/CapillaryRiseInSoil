# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
import skimage.io as io

import sys
sys.path.append('C:\\Users\\marcu\\OneDrive\\Desktop\\PraktikumIII\\CapillaryRiseInSoil\\notebooks')

import amglib.imageutils as amg
import amglib.readers as rd
import amglib.bb as bb

# %%
bbob = rd.readImage('Ashish/noob/AVG_ OB_bb_no_sample_cropped_01.fits').astype(float)
bbs  = rd.readImage('Ashish/noob/AVG_Result_Sample_BB_cropped_02.fits').astype(float)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-85e5d8c45f7b> in <module>
# ----> 1 bbob = rd.readImage('Ashish/noob/AVG_ OB_bb_no_sample_cropped_01.fits').astype(float)
#       2 bbs  = rd.readImage('Ashish/noob/AVG_Result_Sample_BB_cropped_02.fits').astype(float)
#
# ~\OneDrive\Desktop\PraktikumIII\CapillaryRiseInSoil\notebooks\amglib\readers.py in readImage(fname)
#      14
#      15     if ext == 'fits' :
# ---> 16         img = fits.getdata(fname,ext=0).astype('float32')
#      17
#      18     return img
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\convenience.py in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     207                      extname is None and extver is None)
#     208
# --> 209     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     210     try:
#     211         hdu = hdulist[extidx]
#
# ...

# %%
plt.hist(bbob.ravel(),bins=100);

# %% [markdown]
# # Testing bb module

# %%
importlib.reload(bb);

# %%
plt.imshow(110<bbob)

# %%
mask,r,c = bb.get_black_bodies(bbob,greythres=110,R=5)

plt.imshow(10*mask+bbob,interpolation='none',cmap='gray')
plt.colorbar();

# %%
q=bb.compute_scatter_image(bbob,r,c)

# %%
q
# Out:
# array([ 2.67331600e+01, -2.97196705e-03,  1.65842750e-02, -1.21075560e-05,
#        -9.44076076e-06,  1.63731059e-06])

# %%
img=bb.polynomial_image(bbob.shape,q)
plt.imshow(img)
plt.colorbar()

# %%
fig,ax = plt.subplots(2,1,figsize=[10,12])
a0=ax[0].imshow(bbob,vmin=0,vmax=600)

fig.colorbar(a0,ax=ax[0],shrink=0.7);

a1=ax[1].imshow(bbob-img,vmin=0,vmax=600)

fig.colorbar(a1,ax=ax[1],shrink=0.7);
